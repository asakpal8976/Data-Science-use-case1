# %%
n = int(input('Enter a Number'))
if n > 0 :
    print(f'The Number {n} is Positive')
elif n==0:
    print(f'The number {n} is zero')
else:
    print(f'The number {n} is Negative')
# Out:
# Enter a Number -1
# The number -1 is Negative

# %%
List = [1,2,3,4,5, 'Hello']
List
# Out:
# [1, 2, 3, 4, 5, 'Hello']

# %%
List.clear()
List
# Out:
# []

# %%
N = (1,2,3,4)
N
# Out:
# (1, 2, 3, 4)

# %%
import pandas as pd
Data = {
    'Name':['Alice', 'Bob', 'Charlie','David'],
    'Age':[24,27,32,22],
    'City':['Newyork', 'Los-Angeles','Chicago','Houston']
}
df = pd.DataFrame(Data)
df['score'] = [85,90,88,82]
df
# Out:
#       Name  Age         City  score
# 0    Alice   24      Newyork     85
# 1      Bob   27  Los-Angeles     90
# 2  Charlie   32      Chicago     88
# 3    David   22      Houston     82

# %%
Data1 = {
    'Score' : [85,90,88,82]
}
pd.DataFrame(Data1)
# Out:
#    Score
# 0     85
# 1     90
# 2     88
# 3     82

# %%
import pandas as pd
Data = {
    'Name':['Alice', 'Bob', 'Charlie','David'],
    'Age':[24,27,32,22],
    'City':['Newyork', 'Los-Angeles','Chicago','Houston']
}
series1 = pd.Series(Data)
Df = pd.DataFrame(Data)
Data1 = {
    'Score' : [85,90,88,82]
}
Df2 = pd.DataFrame(Data1)
series2 = pd.Series(Data1)

Concatenate_series = series1 + series2
print(Concatenate_series)
# Out:
# Age      NaN
# City     NaN
# Name     NaN
# Score    NaN
# dtype: object

# %%
import pandas as pd
data = {
    'A' : [1,2,'none', 4],
    'B' : ['none', 2, 3, 4],
    'C' : ['none' ,1 , 'none', 4]
}
df = pd.DataFrame(data)
df.fillna(df.mean(), inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       2 data = {
#       3     'A' : [1,2,'none', 4],
#       4     'B' : ['none', 2, 3, 4],
#       5     'C' : ['none' ,1 , 'none', 4]
#       6 }
#       7 df = pd.DataFrame(data)
# ----> 8 df.fillna(df.mean(), inplace = True)
#       9 df
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11694     if isinstance(result, Series):
#   11695         result = result.__finalize__(self, method="mean")
#
# ...

# %%
data(
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[133], line 1
# ----> 1 data(data.mean())
#
# AttributeError: 'dict' object has no attribute 'mean'

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,3,5,7,11]

plt.figure(figsize=(5,4))
plt.plot(x,y)
plt.title('Simple Line Plot', fontweight = 'bold', fontsize = 12, color = 'Maroon')
plt.xlabel('X-Axis', fontweight= 'bold')
plt.ylabel('Y-Axis', fontweight = 'bold')
plt.show()

# %%
import seaborn as sns

# %%
categories = ['A','B','C','D']
values = [4,7,1,8]

plt.bar(x, y )
plt.show()

# %%
import numpy as np

# %%
a = np.random.normal(0,1,1000)

sns.jointplot(a)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
a = np.random.normal(0,1,1000)
plt.hist(a , bins = 30)
plt.title('Histogram', color = 'Green')
print(['a'])
plt.show()
# Out:
# ['a']

# %%
import seaborn as sns
sns.distplot(a)
plt.show()
# Out:
# C:\Users\Raksha Chavan\AppData\Local\Temp\ipykernel_6060\4049141952.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a)

# %%
sns.boxplot(a)
plt.show()

# %%
sns.violinplot(data= a)
sns.swarmplot(data= a, color='maroon')
plt.show()

# %%
categories = ['A', 'B', 'C', 'D']
values = [4, 7, 1, 8]

plt.bar(categories ,values)
plt.show()

# %%
explode = (0.2,0)
plt.pie(values, labels = categories, autopct = '%1.1f%%', explode = explode)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 2
#       1 explode = (0.2,0)
# ----> 2 plt.pie(values, labels = categories, autopct = '%1.1f%%', explode = explode)
#       3 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3558, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3535 @_copy_docstring_and_deprecators(Axes.pie)
#    3536 def pie(
#    3537     x: ArrayLike,
#    (...)
#    3556     data=None,
#    3557 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3558     return gca().pie(
#    3559         x,
#    3560         explode=explode,
#    3561         labels=labels,
#    3562         colors=colors,
#    3563         autopct=autopct,
# ...

# %%
help(plt.pie)
# Out:
# Help on function pie in module matplotlib.pyplot:
#
# pie(x: 'ArrayLike', explode: 'ArrayLike | None' = None, labels: 'Sequence[str] | None' = None, colors: 'ColorType | Sequence[ColorType] | None' = None, autopct: 'str | Callable[[float], str] | None' = None, pctdistance: 'float' = 0.6, shadow: 'bool' = False, labeldistance: 'float | None' = 1.1, startangle: 'float' = 0, radius: 'float' = 1, counterclock: 'bool' = True, wedgeprops: 'dict[str, Any] | None' = None, textprops: 'dict[str, Any] | None' = None, center: 'tuple[float, float]' = (0, 0), frame: 'bool' = False, rotatelabels: 'bool' = False, *, normalize: 'bool' = True, hatch: 'str | Sequence[str] | None' = None, data=None) -> 'tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]'
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
# ...

# %%
plt.scatter(categories, values)
plt.title('Scatter Plot')
plt.show()
