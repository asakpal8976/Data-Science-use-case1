# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Uniform Distribution

# %%
from scipy.stats import uniform
# random numbers from uniform distribution
n = 10000
start = 10
width = 20
data_uniform = uniform.rvs(size=n, loc = start, scale=width)

# %%
ax = sns.distplot(data_uniform,
                  bins=100,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Uniform Distribution ', ylabel='Frequency')
# Out:
# C:\Users\Raksha Chavan\AppData\Local\Temp\ipykernel_16792\3320546192.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_uniform,
# [Text(0.5, 0, 'Uniform Distribution '), Text(0, 0.5, 'Frequency')]

# %%
ax = sns.distplot(data_uniform,
                  bins=100,
                  kde=True,
                  color='skyblue',
                  )
ax.set(xlabel='Uniform Distribution ', ylabel='Frequency')
# Out:
# C:\Users\Raksha Chavan\AppData\Local\Temp\ipykernel_22956\1775538813.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_uniform,
# [Text(0.5, 0, 'Uniform Distribution '), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# # Normal Distribution

# %%
from scipy.stats import norm
# generate random numbers from N(0,1)
data_normal = norm.rvs(size=10000,loc=0,scale=1)

# %%
ax = sns.distplot(data_normal,
                  bins=100,
                  kde=True,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Normal Distribution', ylabel='Frequency')
# Out:
# C:\Users\Raksha Chavan\AppData\Local\Temp\ipykernel_16792\660144129.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_normal,
# [Text(0.5, 0, 'Normal Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# # Poisson Distribution

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=3, size=10000)

# %%
ax = sns.distplot(data_poisson,
                  bins=30,
                  kde=False,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')
# Out:
# C:\Users\Raksha Chavan\AppData\Local\Temp\ipykernel_16792\1391988614.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_poisson,
# [Text(0.5, 0, 'Poisson Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# # Binom Distribution

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=10,p=0.8,size=10000)

# %%
ax = sns.distplot(data_binom,
                  kde=False,
                  color='skyblue',
                  hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Binomial Distribution', ylabel='Frequency')
# Out:
# C:\Users\Raksha Chavan\AppData\Local\Temp\ipykernel_16792\4006488156.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(data_binom,
# [Text(0.5, 0, 'Binomial Distribution'), Text(0, 0.5, 'Frequency')]

# %% [markdown]
# # Bernoulli Distribution

# %%
from scipy.stats import bernoulli
data_bern = bernoulli.rvs(size=10000,p=0.6)

# %%
ax= sns.distplot(data_bern,
                 kde=False,
                 color="skyblue",
                 hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Bernoulli Distribution', ylabel='Frequency')
# Out:
# C:\Users\Raksha Chavan\AppData\Local\Temp\ipykernel_16792\780224195.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax= sns.distplot(data_bern,
# [Text(0.5, 0, 'Bernoulli Distribution'), Text(0, 0.5, 'Frequency')]

# %%
#Write a Python function that generates n random samples from a uniform distribution between a given range [a, b]. 
#The function should return the mean and variance of the generated data. 
#Use this function to generate 1000 samples in the range [0, 10] and display the results.

from scipy.stats import uniform
import seaborn as sns

n = 1000
a = 0
b = 10

uniform_stats = uniform.rvs(a,b,n)
ax = sns.distplot(uniform_stats,
                 kde = True,
                 color = 'skyblue',
                 hist_kws={"linewidth": 15,'alpha':1})
ax.set(x_label = 'Uniform_Dist', y_label = 'frequency')
# Out:
# C:\Users\Raksha Chavan\AppData\Local\Temp\ipykernel_22956\4236484636.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(uniform_stats,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 17
#      12 uniform_stats = uniform.rvs(a,b,n)
#      13 ax = sns.distplot(uniform_stats,
#      14                  kde = True,
#      15                  color = 'skyblue',
#      16                  hist_kws={"linewidth": 15,'alpha':1})
# ---> 17 ax.set(x_label = 'Uniform_Dist', y_label = 'frequency')
#
# ...

# %%
#Create a function that simulates a Bernoulli process with a given probability p of success, repeated n times. 
#Count the number of successes and failures in the process. Demonstrate this for n = 1000 and p = 0.4.

from scipy.stats import bernoulli
n = 1000
p = 0.4

bern_data = bernoulli.rvs(size = n, p = 0.4)

ax = sns.distplot(bern_data,
                 kde = True,
                 color = 'red',
                 hist_kws = {'linewidth' : 15 , 'alpha' : 2 })
ax.set(x_label = 'Bern_Dist', y_label = 'Frequency')
# Out:
# C:\Users\Raksha Chavan\AppData\Local\Temp\ipykernel_22956\367526570.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(bern_data,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 10
#       6 p = 0.4
#       8 bern_data = bernoulli.rvs(size = n, p = 0.4)
# ---> 10 ax = sns.distplot(bern_data,
#      11                  kde = True,
#      12                  color = 'red',
#      13                  hist_kws = {'linewidth' : 15 , 'alpha' : 2 })
# ...

# %%
#Write a Python function to simulate n independent trials of a binomial distribution with k experiments per trial, 
#and probability p of success per experiment. Return the mean number of successes across the trials.
# Use this to simulate 5000 trials where each trial has 10 experiments and the probability of success is 0.5.

from scipy.stats import binom

n = 10
size = 5000
p = 0.5

Binom_data = binom.rvs(size= 5000 , n = 10, p = 0.5)
ax = sns.distplot(Binom_data,
                  kde = False,
                  color = 'pink',
                  hist_kws = {'linewidth' : 15, 'alpha' : 1}
)
ax.set(x_label = 'Binom_dist', y_label = 'Frequency')
# Out:
# C:\Users\Raksha Chavan\AppData\Local\Temp\ipykernel_22956\480220688.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(Binom_data,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 17
#      11 Binom_data = binom.rvs(size= 5000 , n = 10, p = 0.5)
#      12 ax = sns.distplot(Binom_data,
#      13                   kde = False,
#      14                   color = 'pink',
#      15                   hist_kws = {'linewidth' : 15, 'alpha' : 1}
#      16 )
# ...

# %%
#Write a Python function to simulate n occurrences of a Poisson process with a given rate lambda. 
#The function should return the proportion of occurrences where the number of events is greater than or equal to 5.
#Use this to simulate 1000 occurrences with lambda = 3

from scipy.stats import poisson
mu = 3
size = 1000

poisson_data = poisson.rvs(mu = 3, size = 1000)
ax = sns.distplot(poisson_data,
                 kde = True,
                 color = 'Orange',
                 hist_kws = {'linewidth' : 15, 'alpha' : 1})
ax.set(x_label = 'Poisson Dist' , y_label  = 'Frequency')
# Out:
# C:\Users\Raksha Chavan\AppData\Local\Temp\ipykernel_22956\2224947941.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(poisson_data,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 14
#       9 poisson_data = poisson.rvs(mu = 3, size = 1000)
#      10 ax = sns.distplot(poisson_data,
#      11                  kde = True,
#      12                  color = 'Orange',
#      13                  hist_kws = {'linewidth' : 15, 'alpha' : 1})
# ...
